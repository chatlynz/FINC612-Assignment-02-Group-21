# %%
# !pip -q install arch
import warnings
import numpy as np
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
import matplotlib.pyplot as plt

from arch import arch_model
from arch.unitroot import KPSS, ZivotAndrews
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy.stats import t, norm

warnings.filterwarnings("ignore")
plt.style.use("ggplot")

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_PATH  = "/content/drive/MyDrive/FINC612 A02/data.xlsx"
SHEET_NAME = "Part3"
COLUMN     = "x"

df = pd.read_excel(DATA_PATH, sheet_name=SHEET_NAME)
data = pd.to_numeric(df[COLUMN], errors="coerce").dropna()

# %%
#1a: Estimate the Andrews-Zivot and KPSS statistics
print("\n=== Zivot-Andrews Test (Structural Break) ===")
za_test = ZivotAndrews(data, method="bic")
print(za_test.summary())

print("\n=== KPSS Test ===")
kpss_test = KPSS(data)
print(kpss_test.summary())
# Out:
# === Zivot-Andrews Test (Structural Break) ===
#         Zivot-Andrews Results
# =====================================
# Test Statistic                -32.925
# P-value                         0.000
# Lags                                0
# -------------------------------------
#
# Trend: Constant
# Critical Values: -5.28 (1%), -4.81 (5%), -4.57 (10%)
# Null Hypothesis: The process contains a unit root with a single structural break.
# Alternative Hypothesis: The process is trend and break stationary.
#
# === KPSS Test ===
#     KPSS Stationarity Test Results
# =====================================
# Test Statistic                  0.032
# P-value                         0.968
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: 0.74 (1%), 0.46 (5%), 0.35 (10%)
# Null Hypothesis: The process is weakly stationary.
# Alternative Hypothesis: The process contains a unit root.

# %% [markdown]
# 1a.
#
# The Zivot–Andrews test gave a statistic of −32.925 (p = 0.000), far below all critical values, so we reject the null of a unit root and conclude the series is stationary with a possible break.
#
# The KPSS test gave a statistic of 0.032 (p = 0.968), well below critical values, so we fail to reject the null of stationarity.
#
# Overall, both tests confirm the data are stationary.

# %%
#1b.Conduct the Ljung-Box test on the series and the squared series.
# Ljung-Box test on returns
lb_resid = acorr_ljungbox(data, lags=30, return_df=True)
print("Ljung-Box test on residuals:")
print(lb_resid)


# Ljung-Box test on squared residuals (for ARCH effects)
lb_sq_resid = acorr_ljungbox(data**2, lags=30, return_df=True)
print("\nLjung-Box test on squared residuals (ARCH effects):")
print(lb_sq_resid)
# Out:
# Ljung-Box test on residuals:
#       lb_stat  lb_pvalue
# 1    1.401812   0.236420
# 2    5.273527   0.071593
# 3    5.290463   0.151722
# 4    5.634645   0.228145
# 5    6.300419   0.278074
# 6    7.327420   0.291626
# 7   12.183455   0.094685
# 8   12.795718   0.119074
# 9   14.429395   0.107850
# 10  14.587142   0.147855
# 11  17.008488   0.107625
# 12  18.622085   0.098066
# 13  19.097147   0.120122
# 14  19.480129   0.147402
# 15  21.077873   0.134360
# 16  21.145333   0.172992
# 17  21.173125   0.218642
# 18  22.176770   0.224232
# 19  22.867865   0.243212
# 20  23.004044   0.288596
# 21  24.958970   0.248945
# 22  25.737643   0.263117
# 23  27.620363   0.230479
# 24  27.973927   0.261141
# 25  30.715144   0.198625
# 26  30.715202   0.239047
# 27  30.748573   0.281587
# 28  30.842359   0.324125
# 29  32.250016   0.309007
# 30  32.412610   0.348590
#
# Ljung-Box test on squared residuals (ARCH effects):
#        lb_stat     lb_pvalue
# 1    62.268840  2.996288e-15
# 2   144.595584  3.994551e-32
# 3   206.217766  1.912384e-44
# 4   233.117338  2.814932e-49
# 5   263.774639  6.076636e-55
# 6   293.014817  2.566011e-60
# 7   312.681015  1.182329e-63
# 8   328.477866  3.533226e-66
# 9   334.548521  1.200043e-66
# 10  337.737165  1.590884e-66
# 11  339.397756  4.236560e-66
# 12  340.936313  1.144210e-65
# 13  341.112936  5.734184e-65
# 14  341.475009  2.521893e-64
# 15  341.830310  1.071934e-63
# 16  341.938136  4.955797e-63
# 17  343.277119  1.230334e-62
# 18  343.621893  4.774416e-62
# 19  345.621602  8.198453e-62
# 20  345.693506  3.434603e-61
# 21  345.713888  1.436375e-60
# 22  349.777717  8.709745e-61
# 23  350.937870  2.041828e-60
# 24  352.829045  3.331629e-60
# 25  355.284597  4.105606e-60
# 26  363.170976  3.949796e-61
# 27  367.268436  2.215095e-61
# 28  374.404465  2.991851e-62
# 29  375.979523  5.328464e-62
# 30  377.496792  9.612667e-62

# %% [markdown]
# 1b.
#
# The Ljung–Box test on residuals shows that all p-values are above 0.05, so there is no autocorrelation in the mean. The test on squared residuals gives p-values that are essentially zero. We strongly reject the null of no autocorrelation in the squared series, which are ARCH effects.

# %%
#1c.Visualize the ACF and PACF plots.

# Plot ACF and PACF of Series
fig, ax = plt.subplots(2, 1, figsize=(10, 6))
plot_acf(data, lags=30, ax=ax[0])
plot_pacf(data, lags=30, ax=ax[1])
ax[0].set_title("ACF of Series")
ax[1].set_title("PACF of Series")
plt.show()

# Plot ACF and PACF of Squared Series
fig, ax = plt.subplots(2, 1, figsize=(10, 6))
plot_acf(data**2, lags=30, ax=ax[0])
plot_pacf(data**2, lags=30, ax=ax[1])
ax[0].set_title("ACF of Squared Series")
ax[1].set_title("PACF of Squared Series")
plt.show()

# %% [markdown]
# 1c.
#
# The residuals show no serial correlation in the mean, but the squared residuals display strong autocorrelation, which is consistent with volatility clustering.
#
# According to the lecture slides, GARCH(1,1) is often sufficient for financial return series, so the expected optimal model is GARCH(1,1).

# %%
# 2a.Estimate the GARCH(1,1) model
garch_model = arch_model(data, mean='Constant', vol='GARCH', p=1, q=1, dist='normal').fit(disp='off')
print(garch_model.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -1326.14
# Distribution:                  Normal   AIC:                           2660.27
# Method:            Maximum Likelihood   BIC:                           2679.90
#                                         No. Observations:                 1000
# Date:                Sun, Sep 28 2025   Df Residuals:                      999
# Time:                        09:10:10   Df Model:                            1
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu             0.0783  2.537e-02      3.087  2.025e-03 [2.858e-02,  0.128]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.0845  1.729e-02      4.885  1.034e-06 [5.059e-02,  0.118]
# alpha[1]       0.2520  3.470e-02      7.261  3.847e-13   [  0.184,  0.320]
# beta[1]        0.6722  3.328e-02     20.199  1.007e-90   [  0.607,  0.737]
# ==========================================================================
#
# Covariance estimator: robust

# %% [markdown]
# 2a.
#
# The GARCH(1,1) model shows that the mean (mu = 0.0783, p = 0.002) is significantly positive. Both alpha (0.2520) and beta (0.6722) are highly significant, indicating strong volatility clustering. Since alpha + beta = 0.9242 < 1, the process is stationary, but volatility is highly persistent, which is consistent with typical financial return series.

# %%
# 2b.Perform the sign bias test.
def sign_bias_test(std_resid):

    # Create indicator variables
    sign_bias = (std_resid.shift(1) < 0).astype(int)      # I_{t-1}^{-}
    neg_size = sign_bias * std_resid.shift(1)             # I_{t-1}^{-} * e_{t-1}
    pos_size = (1 - sign_bias) * std_resid.shift(1)       # I_{t-1}^{+} * e_{t-1}

    # Get squared residuals as proxy for conditional variance
    squared = std_resid ** 2

    # Run regression for: squared residuals ~ constant + sign bias
    X1 = sm.add_constant(sign_bias)
    reg1 = sm.OLS(squared, X1, missing='drop').fit()
    print("Sign Bias Test")
    print(reg1.summary())

    # Negative Size Bias
    X2 = sm.add_constant(neg_size)
    reg2 = sm.OLS(squared, X2, missing='drop').fit()
    print("\nNegative Size Bias Test")
    print(reg2.summary())

    # Positive Size Bias
    X3 = sm.add_constant(pos_size)
    reg3 = sm.OLS(squared, X3, missing='drop').fit()
    print("\nPositive Size Bias Test")
    print(reg3.summary())

    # Step 8: Joint test (F-test)
    X_joint = sm.add_constant(pd.concat([sign_bias, neg_size, pos_size], axis=1))
    reg_joint = sm.OLS(squared, X_joint, missing='drop').fit()
    print("\nJoint Test for Sign and Size Bias")
    print(reg_joint.summary())

std_resid = garch_model.std_resid
sign_bias_test (std_resid)
# Out:
# Sign Bias Test
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     4.484
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):             0.0345
# Time:                        09:10:10   Log-Likelihood:                -1757.8
# No. Observations:                1000   AIC:                             3520.
# Df Residuals:                     998   BIC:                             3529.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9031      0.064     14.216      0.000       0.778       1.028
# std_resid      0.1882      0.089      2.117      0.034       0.014       0.363
# ==============================================================================
# Omnibus:                      624.813   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5910.175
# Skew:                           2.810   Prob(JB):                         0.00
# Kurtosis:                      13.501   Cond. No.                         2.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Negative Size Bias Test
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.363
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):              0.243
# Time:                        09:10:10   Log-Likelihood:                -1758.0
# No. Observations:                 999   AIC:                             3520.
# Df Residuals:                     997   BIC:                             3530.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9632      0.054     17.694      0.000       0.856       1.070
# std_resid     -0.0855      0.073     -1.167      0.243      -0.229       0.058
# ==============================================================================
# Omnibus:                      625.964   Durbin-Watson:                   2.135
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5915.621
# Skew:                           2.821   Prob(JB):                         0.00
# Kurtosis:                      13.502   Cond. No.                         2.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Positive Size Bias Test
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     9.163
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):            0.00253
# Time:                        09:10:10   Log-Likelihood:                -1754.2
# No. Observations:                 999   AIC:                             3512.
# Df Residuals:                     997   BIC:                             3522.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0920      0.054     20.291      0.000       0.986       1.198
# std_resid     -0.2434      0.080     -3.027      0.003      -0.401      -0.086
# ==============================================================================
# Omnibus:                      621.504   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5824.850
# Skew:                           2.797   Prob(JB):                         0.00
# Kurtosis:                      13.423   Cond. No.                         2.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Joint Test for Sign and Size Bias
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.098
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):             0.0261
# Time:                        09:10:10   Log-Likelihood:                -1754.1
# No. Observations:                 999   AIC:                             3516.
# Df Residuals:                     995   BIC:                             3536.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0940      0.108     10.100      0.000       0.881       1.307
# std_resid      0.0294      0.150      0.195      0.845      -0.266       0.325
# std_resid      0.0385      0.101      0.383      0.702      -0.159       0.236
# std_resid     -0.2452      0.113     -2.167      0.030      -0.467      -0.023
# ==============================================================================
# Omnibus:                      621.452   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5830.397
# Skew:                           2.796   Prob(JB):                         0.00
# Kurtosis:                      13.430   Cond. No.                         5.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 2b.
#
# From the Sign Bias Test results, we can see:
# - Sign Bias Test: coefficient = 0.1882, p = 0.034 which is significant and indicates a sign effect.
# - Negative Size Bias Test: coefficient = -0.0855, p = 0.234 which is not significant.
# - Positive Size Bias Test: coefficient = -0.2434, p = 0,003 which is significant and indicates a positive size effect.
# - Joint Test: prob = 0.0261 which is significant and indicates at least one of the Bias effect.
#
# Overall, the GARCH(1.1) model is not appropriate.

# %%
# Estimate the EGARCH model to proceed
egarch_model = arch_model(data, mean='Constant', vol='EGARCH', p=1, o=1, q=1, dist='normal').fit(disp='off')
print(egarch_model.summary())

std_resid = egarch_model.std_resid
sign_bias_test (std_resid)
# Out:
#                      Constant Mean - EGARCH Model Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                     EGARCH   Log-Likelihood:               -1318.81
# Distribution:                  Normal   AIC:                           2647.63
# Method:            Maximum Likelihood   BIC:                           2672.17
#                                         No. Observations:                 1000
# Date:                Sun, Sep 28 2025   Df Residuals:                      999
# Time:                        09:10:10   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu             0.0371  2.555e-02      1.451      0.147 [-1.301e-02,8.714e-02]
#                                Volatility Model
# ==============================================================================
#                  coef    std err          t      P>|t|        95.0% Conf. Int.
# ------------------------------------------------------------------------------
# omega         -0.0242  1.232e-02     -1.964  4.951e-02 [-4.836e-02,-5.208e-05]
# alpha[1]       0.3787  4.637e-02      8.167  3.166e-16       [  0.288,  0.470]
# gamma[1]      -0.1442  3.007e-02     -4.795  1.625e-06    [ -0.203,-8.525e-02]
# beta[1]        0.9027  1.984e-02     45.490      0.000       [  0.864,  0.942]
# ==============================================================================
#
# Covariance estimator: robust
# Sign Bias Test
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                 0.0008560
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):              0.977
# Time:                        09:10:10   Log-Likelihood:                -1723.7
# No. Observations:                1000   AIC:                             3451.
# Df Residuals:                     998   BIC:                             3461.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0002      0.060     16.620      0.000       0.882       1.118
# std_resid     -0.0025      0.086     -0.029      0.977      -0.171       0.166
# ==============================================================================
# Omnibus:                      609.434   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5956.837
# Skew:                           2.699   Prob(JB):                         0.00
# Kurtosis:                      13.669   Cond. No.                         2.60
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Negative Size Bias Test
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9582
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):              0.328
# Time:                        09:10:10   Log-Likelihood:                -1721.9
# No. Observations:                 999   AIC:                             3448.
# Df Residuals:                     997   BIC:                             3458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0284      0.052     19.733      0.000       0.926       1.131
# std_resid      0.0711      0.073      0.979      0.328      -0.071       0.214
# ==============================================================================
# Omnibus:                      607.653   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5917.820
# Skew:                           2.693   Prob(JB):                         0.00
# Kurtosis:                      13.638   Cond. No.                         2.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Positive Size Bias Test
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9441
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):              0.331
# Time:                        09:10:10   Log-Likelihood:                -1721.9
# No. Observations:                 999   AIC:                             3448.
# Df Residuals:                     997   BIC:                             3458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0292      0.053     19.526      0.000       0.926       1.133
# std_resid     -0.0735      0.076     -0.972      0.331      -0.222       0.075
# ==============================================================================
# Omnibus:                      607.266   Durbin-Watson:                   2.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5908.650
# Skew:                           2.691   Prob(JB):                         0.00
# Kurtosis:                      13.629   Cond. No.                         2.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Joint Test for Sign and Size Bias
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.242
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):              0.293
# Time:                        09:10:10   Log-Likelihood:                -1720.5
# No. Observations:                 999   AIC:                             3449.
# Df Residuals:                     995   BIC:                             3469.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1188      0.103     10.827      0.000       0.916       1.322
# std_resid     -0.0097      0.147     -0.066      0.947      -0.297       0.278
# std_resid      0.1348      0.102      1.328      0.184      -0.064       0.334
# std_resid     -0.1482      0.106     -1.400      0.162      -0.356       0.059
# ==============================================================================
# Omnibus:                      604.668   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5840.619
# Skew:                           2.679   Prob(JB):                         0.00
# Kurtosis:                      13.565   Cond. No.                         5.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 2b. Estimate the EGARCH model to proceed
#
# From the Sign Bias Test results, we can see:
# - Sign Bias Test: coefficient = -0.0025, p = 0.977, which is not significant.
# - Negative Size Bias Test: coefficient = 0.0711, p = 0.328, which is not significant.
# - Positive Size Bias Test: coefficient = -0.0735, p = 0.331, which is not significant.
# - Joint Test: prob = 0.293, which is not significant.
#
# Compared to GARCH(1.1) model, the results of EGARCH are not significant.
#
# Overall, the EGARCH model is more suitable.

# %%
# Estimate the GJR_GARCH model to proceed
gjr_model = arch_model(data, mean='Constant', vol='GARCH', p=1, o=1, q=1, dist='normal').fit(disp='off')
print(gjr_model.summary())

std_resid = gjr_model.std_resid
sign_bias_test (std_resid)
# Out:
#                    Constant Mean - GJR-GARCH Model Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                  GJR-GARCH   Log-Likelihood:               -1317.12
# Distribution:                  Normal   AIC:                           2644.23
# Method:            Maximum Likelihood   BIC:                           2668.77
#                                         No. Observations:                 1000
# Date:                Sun, Sep 28 2025   Df Residuals:                      999
# Time:                        09:10:11   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu             0.0427  2.583e-02      1.654  9.807e-02 [-7.896e-03,9.335e-02]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.0848  1.596e-02      5.314  1.075e-07 [5.352e-02,  0.116]
# alpha[1]       0.1086  3.285e-02      3.305  9.485e-04 [4.420e-02,  0.173]
# gamma[1]       0.2633  6.285e-02      4.189  2.806e-05   [  0.140,  0.386]
# beta[1]        0.6829  3.276e-02     20.843  1.748e-96   [  0.619,  0.747]
# ==========================================================================
#
# Covariance estimator: robust
# Sign Bias Test
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1010
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):              0.751
# Time:                        09:10:11   Log-Likelihood:                -1729.2
# No. Observations:                1000   AIC:                             3462.
# Df Residuals:                     998   BIC:                             3472.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9858      0.061     16.276      0.000       0.867       1.105
# std_resid      0.0274      0.086      0.318      0.751      -0.142       0.197
# ==============================================================================
# Omnibus:                      617.383   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6101.545
# Skew:                           2.743   Prob(JB):                         0.00
# Kurtosis:                      13.786   Cond. No.                         2.60
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Negative Size Bias Test
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9918
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):              0.320
# Time:                        09:10:11   Log-Likelihood:                -1727.4
# No. Observations:                 999   AIC:                             3459.
# Df Residuals:                     997   BIC:                             3469.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0295      0.052     19.630      0.000       0.927       1.132
# std_resid      0.0724      0.073      0.996      0.320      -0.070       0.215
# ==============================================================================
# Omnibus:                      616.011   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6069.286
# Skew:                           2.739   Prob(JB):                         0.00
# Kurtosis:                      13.761   Cond. No.                         2.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Positive Size Bias Test
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.159
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):              0.282
# Time:                        09:10:11   Log-Likelihood:                -1727.3
# No. Observations:                 999   AIC:                             3459.
# Df Residuals:                     997   BIC:                             3469.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0328      0.053     19.500      0.000       0.929       1.137
# std_resid     -0.0824      0.077     -1.076      0.282      -0.233       0.068
# ==============================================================================
# Omnibus:                      615.330   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6050.354
# Skew:                           2.736   Prob(JB):                         0.00
# Kurtosis:                      13.743   Cond. No.                         2.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Joint Test for Sign and Size Bias
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              std_resid   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.473
# Date:                Sun, 28 Sep 2025   Prob (F-statistic):              0.220
# Time:                        09:10:11   Log-Likelihood:                -1725.7
# No. Observations:                 999   AIC:                             3459.
# Df Residuals:                     995   BIC:                             3479.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0889      0.104     10.472      0.000       0.885       1.293
# std_resid      0.0673      0.147      0.456      0.648      -0.222       0.356
# std_resid      0.1719      0.102      1.693      0.091      -0.027       0.371
# std_resid     -0.1293      0.107     -1.208      0.227      -0.339       0.081
# ==============================================================================
# Omnibus:                      612.846   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6000.054
# Skew:                           2.723   Prob(JB):                         0.00
# Kurtosis:                      13.700   Cond. No.                         5.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 2b. Estimate the GJR_GARCH model to proceed
#
# From the Sign Bias Test results, we can see:
# - Sign Bias Test: coefficient = 0.0274, p = 0.751, which is not significant.
# - Negative Size Bias Test: coefficient = 0.0724, p = 0.320, which is not significant.
# - Positive Size Bias Test: coefficient = -0.0824, p = 0.282, which is not significant.
# - Joint Test: prob = 0.220, which is not significant.
#
# Compared to EGARCH model, GJR_GARCH has low AIC(2644.23) and BIC(2668.77).
#
# Overall, the GJR_GARCH model is more suitable.

# %%
#3a. Conduct the Ljung-Box test on the standardized residuals and squared standardized residuals.
result = arch_model(data, mean='Constant', vol='GARCH', p=1, o=1, q=1, dist='t').fit(disp='off')
print(result.summary())

# Get raw residuals (εₜ)
std_residuals = result.std_resid.dropna()

# Ljung-Box test on standardized residuals
lb_resid = acorr_ljungbox(std_residuals, lags=30, return_df=True)
print("Ljung-Box test on standardized residuals:")
print(lb_resid)
# Significant autocorrelations on returns

# Ljung-Box test on squared standardized residuals
lb_sq_resid = acorr_ljungbox(std_residuals**2, lags=30, return_df=True)
print("\nLjung-Box test on squared standardized residuals):")
print(lb_sq_resid)
# Out:
#                       Constant Mean - GJR-GARCH Model Results
# ====================================================================================
# Dep. Variable:                            x   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                        GJR-GARCH   Log-Likelihood:               -1317.41
# Distribution:      Standardized Student's t   AIC:                           2646.81
# Method:                  Maximum Likelihood   BIC:                           2676.26
#                                               No. Observations:                 1000
# Date:                      Sun, Sep 28 2025   Df Residuals:                      999
# Time:                              09:10:11   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu             0.0431  2.586e-02      1.666  9.568e-02 [-7.598e-03,9.378e-02]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.0846  1.589e-02      5.323  1.018e-07 [5.345e-02,  0.116]
# alpha[1]       0.1089  3.297e-02      3.303  9.569e-04 [4.428e-02,  0.174]
# gamma[1]       0.2626  6.268e-02      4.189  2.804e-05   [  0.140,  0.385]
# beta[1]        0.6830  3.288e-02     20.774  7.429e-96   [  0.619,  0.747]
#                                Distribution
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# nu           135.1594     44.793      3.017  2.549e-03 [ 47.367,2.230e+02]
# ==========================================================================
#
# Covariance estimator: robust
# Ljung-Box test on standardized residuals:
#       lb_stat  lb_pvalue
# 1    0.010113   0.919899
# 2    0.605244   0.738878
# 3    0.616498   0.892645
# 4    0.861809   0.929975
# 5    1.005007   0.962161
# 6    1.329065   0.970031
# 7    1.803398   0.969916
# 8    1.803462   0.986456
# 9    2.565270   0.979076
# 10   2.593049   0.989449
# 11   4.723751   0.943804
# 12   6.503228   0.888624
# 13   7.586926   0.869432
# 14   8.801765   0.843536
# 15  13.202259   0.586679
# 16  13.266637   0.653171
# 17  13.517250   0.700930
# 18  13.523203   0.759602
# 19  14.491584   0.754318
# 20  14.531836   0.802540
# 21  14.948502   0.825527
# 22  14.958864   0.863997
# 23  16.456292   0.835051
# 24  17.542880   0.824604
# 25  19.529269   0.771062
# 26  19.537017   0.812974
# 27  19.855686   0.836757
# 28  20.882588   0.830210
# 29  21.668636   0.833648
# 30  21.824092   0.860366
#
# Ljung-Box test on squared standardized residuals):
#       lb_stat  lb_pvalue
# 1    3.815838   0.050770
# 2    4.305302   0.116176
# 3    4.312360   0.229650
# 4    9.070585   0.059359
# 5    9.109303   0.104783
# 6    9.800856   0.133293
# 7   10.813597   0.146959
# 8   10.825031   0.211812
# 9   11.215518   0.261225
# 10  12.084798   0.279421
# 11  12.087050   0.357136
# 12  13.862509   0.309574
# 13  17.376803   0.182646
# 14  18.726467   0.175667
# 15  20.212122   0.163946
# 16  20.885845   0.182940
# 17  20.890865   0.231210
# 18  21.014426   0.278686
# 19  22.644567   0.253360
# 20  23.001860   0.288703
# 21  24.485683   0.270126
# 22  27.142278   0.205872
# 23  29.490905   0.164581
# 24  29.603775   0.198233
# 25  29.770950   0.232980
# 26  29.961369   0.269215
# 27  33.281502   0.187938
# 28  33.606669   0.214124
# 29  33.632348   0.252973
# 30  36.965140   0.178162

# %%
# 3b.

# %run "/content/drive/MyDrive/FINC612 A02/functions.ipynb"
returns = data.dropna()

quantile = 0.95  # 95% confidence level
fitted_mean = pd.Series(result.params["mu"], index=returns.index)
VaR = fitted_mean + t.ppf(1-quantile, df=result.params["nu"])*result.conditional_volatility
violations = VaR.values > returns.values
violations_ind = np.where(violations)[0]
print(failure_rate(violations))
print(len(violations_ind) / len(returns))
CVaR = fitted_mean - result.conditional_volatility * t.pdf(t.ppf(quantile, df=result.params["nu"]), df=result.params["nu"]) / (1-quantile)

plt.plot(returns, color='black')
plt.plot(VaR, label="VaR")
plt.plot(CVaR, label="CVaR")
plt.plot(returns.iloc[violations], marker='p', markersize=5, linestyle='')
plt.title("Value-at-Risk (VaR) at {}% confidence level".format(round(100*quantile)))

kupiec_test(violations, var_conf_level=quantile, conf_level=0.99)
duration_test(violations, conf_level=0.99)
# Out:
# Failure rate of 5.5%
# {'failure rate': np.float64(0.055)}
# 0.055
# CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
# {'weibull exponential': array([1.04729489]),
#  'unrestricted log-likelihood': array([-210.10677945]),
#  'restricted log-likelihood': array([-210.20964655]),
#  'log-likelihood': array([0.20573421]),
#  'log-likelihood ratio test statistic': array([0.65013164]),
#  'null hypothesis': 'Duration Between Exceedances have no memory (Weibull b=1 = Exponential)',
#  'decision': 'Fail to Reject H0'}

# %% [markdown]
# ### Explain the disadvantages of the GARCH model and the advantages of the DCC-GARCH model. Provide a detailed explanation.
# Disadvantages of the GARCH Model:
# - Only one series at a time, it models volatility for one asset.
# - Reacts to the news the same way: e.g. A standard GARCH model reacts the same way to good and bad news. In reality, bad news often causes more and volatility than good news.
# Advantages of the DCC-GARCH Model:
# - Correlations Aren't Static. DCC-GARCH avoids rolling-window issues since it does not rely on a rolling-window approach.
# - Sees the Big Picture. By using VIRFs within DCC-GARCH, the model provides more detailed and accurate insights.
